# %%
from utils import highlight_differences
import os
import json
import matplotlib.pyplot as plt
import numpy as np

# %%
#error_dir = "work/errors/val"
error_dir = "work/errors/train"
project_dir = "/home/efittsc1/projects/latin-transcription/"
error_dir = project_dir + error_dir
show_n_errors = 10

# %%
def visualise_result(data):
    image_path = data["filename"]
    image_name = os.path.basename(image_path)
    truth = data["truth"]
    pred = data["prediction"]

    image = np.load(os.path.join(project_dir, image_path))

    highlighted_pred_char = highlight_differences(pred, truth, level='char')
    highlighted_pred_word = highlight_differences(pred, truth, level='word')


    print(f"\nImage Path: {image_path}")
    print(f"Ground Truth:\t\t{truth}")
    print(f"Prediction (char_diff): {highlighted_pred_char}")
    print(f"Prediction (char_diff): {highlighted_pred_word}")


    plt.figure(figsize=(10, 4))
    plt.imshow(image, cmap='gray')
    plt.title(f"Line: {image_name}")
    plt.axis('off')
    plt.show()

# %%
for error_json in os.listdir(error_dir)[:min(show_n_errors, len(os.listdir(error_dir)))]:
    with open(os.path.join(error_dir, error_json), 'r') as f:
        data = json.load(f)
    visualise_result(data)
# Out:
# Image Path: work/processed_data/JUST1-633m48d_line_6.npy
# Ground Truth:		et in quas iidem Thomas et Juliana non habent ingressum nisi per Iohannem de Boketon cui Willelmus de Nutriuilla
# Prediction (char_diff): et in quas iidem Thomas et Juliana non habent ingressum nisi per Iohannem de Boketon cui Willelmus de Nuitriuilla
# Prediction (char_diff): et in quas iidem Thomas et Juliana non habent ingressum nisi per Iohannem de Boketon cui Willelmus de Nuitriuilla
# Image Path: work/processed_data/memb1_line_3.npy
# Ground Truth:		valenciam octo librarum ibidem inventa ceperunt et asportaverunt et herbam suam ibidem nuper crescentem ad valenciam quadraginta
# Prediction (char_diff): valenciam ino librarum ibidem inventim ceperunt et asportavveruntrt herbam suam ibidem nuper crescentem ad valenciam quaddraginta
# Prediction (char_diff): valenciam ino lbrarum ibidem inventim ceperunt et asportavverntrt herbam suam ibidem nuper crescentem ad valenciam quaddragina
# Image Path: work/processed_data/JUST1-734m11_line_10.npy
# Ground Truth:		habere debet nec solet. nec aliquis antecessorum suorum ibi vnquam habuit set reuera dicit quod quidam Stephanus de Hope patronus
# Prediction (char_diff): habere debet nec solet. nec aliquis antecessorum suorum ibi vnquam habuit set reuera dicit quod quidam Stephanus de Hope pacronus
# Prediction (char_diff): habere debet nec solet. nec aliquis antecessorum suorum ibi vnquam habuit set reuera dicit quod quidam Stephanus de Hope pacronus
# Image Path: work/processed_data/JUST1-734m18_line_0.npy
# Ground Truth:		¶ Galfridus Cubaud et Willelmus le Svan essoniator Walteri filii Ricardi. optulerunt. se iiii die versus Alanum filium Roadi et Matillidem uxorem ejus
# Prediction (char_diff): ¶ Galfridus Cubaud et Willelmus le Svan essoniator Walteri filii Ricardi. optulerunt. se iiii die versus Alanum filium Roadi et Matillidem uxorem ejus
# Prediction (char_diff): ¶ Galfridus Cubaud et Willelmus le Svan essoniator Walteri filii Ricardi. optulerunt se iiii die versus Alanum filium Roadi et Matillidem uxorem ejus
# Image Path: work/processed_data/JUST1-633m9d_line_9.npy
# Ground Truth:		Et Simon per Willelmum de Holcote attornatum suum venit et defendit vim et iniuriam quando etc. Et dicit quod ad ipsum et non
# Prediction (char_diff): Et Simon per Willelmum de Holcote attornatum suum venit et defendit vim et iniuriam quando etc. Et dicit quod ad ipsum et non
# Prediction (char_diff): Et Simon per Willelmum de Holcote attornatum suum venit e defendit vim et iniuriam quando etc. Et dicit quod ad ipsum et non
# Image Path: work/processed_data/JUST1-633m80_line_4.npy
# Ground Truth:		idem Robertus de domibus et gardinis in Rissheton que Robertus quondam prior ecclesie beate Marie de Huntyndon pre
# Prediction (char_diff): idem Robertus de domibus et gardinis in Rissheton que Robertus quondam prior ecclesie beate Marie de Huntyndon pre
# Prediction (char_diff): idem Robertus de domibus et gardinis in Rissheton que Robertus quondam prior eccese beate Marie de Huntyndon pre
# Image Path: work/processed_data/JUST1-633m47d_line_1.npy
# Ground Truth:		tatem suam et in quam jdem Adam non habet ingressum nisi post dimissionem quam Iohannes le Clerk de Haselbech
# Prediction (char_diff): tatem suam et in quam. jdem Adam non habet ingressum nisi post dimissionem quam Iohannes le Clerk de Haselbech
# Prediction (char_diff): tatem suam et in quam. jdem Adam non habet ingressum nisi post dimissionem quam Iohannes le Clerk de Haselbech
# Image Path: work/processed_data/JUST1-635m6_line_11.npy
# Ground Truth:		et de exitibus terre eiusdem per medium tempus .ix. s. pro tribus annis vnde vicecomes respondeat. Et quia Matillis vxor predicti Willelmi cepit
# Prediction (char_diff): et de exitibus terre eiusdem per medium tempus .ix. so. pro tribus annis vnde vicecomes respondeat. Et quia Matillis vxor predicti Willelmi cepit
# Prediction (char_diff): et de exitibus terre eiusdem per medium tempus .ix. so. pro tribus annis vnde vicecomes respondeat. Et quia Matillis vxor predicti Willelmi cepit
# Image Path: work/processed_data/JUST1-734m3_line_8.npy
# Ground Truth:		de se et heredibus suis predictis Radulfo et Matillidi et heredibus ipsius Matillidis inperpetuum. Et pro hac et recognicione etc. predicti Radulfus
# Prediction (char_diff): de se et heredibus suis predictis Radulfo et Matillidi et heredibus ipsius Matillidis inperpetuum. Et pro hac et recognicione etc. predicti Radulfus
# Prediction (char_diff): de se et heredibus suis predictis Radulfo et Matillidi et heredibus ipsius Matillidis inperpetuum. Et pro hac et recognicine etc. predicti Radulfus
# Image Path: work/processed_data/JUST1-734m13d_line_25.npy
# Ground Truth:		de Werkewode. Dicit enim quod semper post confeccionem predicte carte fuit ipse in seisina de capiendo estoveria sua
# Prediction (char_diff): de Werkewode. Dicit enim quod semper post confeccionem predicte carte fuit ipse in seisina de capiendo esto veria sua
# Prediction (char_diff): de Werkewode. Dicit enim quod semper post confeccionem predicte carte fuit ipse in seisina de capiendo esto veria sua
