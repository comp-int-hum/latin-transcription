# %%
from utils import highlight_differences
import os
import json
import matplotlib.pyplot as plt
import numpy as np

# %%
error_dir = "work/errors/val"
# error_dir = "work/errors/test"
project_dir = "/home/efittsc1/projects/latin-transcription/"
error_dir = project_dir + error_dir

# %%
def visualise_result(data):
    image_path = data["filename"]
    image_name = os.path.basename(image_path)
    truth = data["truth"]
    pred = data["prediction"]

    image = np.load(os.path.join(project_dir, image_path))

    highlighted_pred_char = highlight_differences(pred, truth, level='char')
    highlighted_pred_word = highlight_differences(pred, truth, level='word')


    print(f"\nImage Path: {image_path}")
    print(f"Ground Truth: {truth}")
    print(f"Prediction (char-level differences): {highlighted_pred_char}")
    print(f"Prediction (word-level differences): {highlighted_pred_word}")


    plt.figure(figsize=(10, 4))
    plt.imshow(image, cmap='gray')
    plt.title(f"Line: {image_name}")
    plt.axis('off')
    plt.show()

# %%
for error_json in os.listdir(error_dir)[:10]:
    with open(os.path.join(error_dir, error_json), 'r') as f:
        data = json.load(f)
    visualise_result(data)
# Out:
# Image Path: work/processed_data/JUST1-633m22_line_13.npy
# Ground Truth: Boketon jurati. Qui se ipsos elegerunt et eciam Thomam de Werdon Robertum de Hotot deClopton Willelmum de
# Prediction (char-level differences): Boketon iuratores qui se ipsos elegerunt et eciam Thomam de Werdon Robertum de Hotot de Clopton. Willelmum de
# Prediction (word-level differences): Boketon iuratores qui se ipsos elegerunt et eciam Thomam de Werdon Robertum de Hotot de Clopton. Willelmum de
# Image Path: work/processed_data/JUST1-734m13d_line_15.npy
# Ground Truth: predicta estoveria sua in predicto bosco suo de Wercwode modo est in seisina de predictis estoveriis suis capiendis in
# Prediction (char-level differences): predicta estaveria sua in predicto bosco suo de Werewode et modo est in seisina de predictis Estoveriis suis capiendis In
# Prediction (word-level differences): predicta estavera sua in predicto bosco suo de Werewode et modo est in seisina de predictis Estoveriis suis capiendis In
# Image Path: work/processed_data/JUST1-734m17_line_14.npy
# Ground Truth: inperpetuum per cartam ipsius Simonis quam profert de feoffamento et que hoc testatur unde dicit quod si
# Prediction (char-level differences): imperpetuum per caritam ipsius Simonis quam profort de feafftamento et que hoc testatur unde dicit quod si
# Prediction (word-level differences): imperpetuum per caritam ipsius Simonis quam profort de feafftamento et que hoc testatur unde dicit quod si
# Image Path: work/processed_data/JUST1-734m3a_line_1.npy
# Ground Truth: primam etc. Et unde queritur quod disseisivit eum de uno mesuagio et dimidia virgata terre. Et Michaelis venit et dicit quod assisa non deberi de
# Prediction (char-level differences): primam etc. Et unde queritur quod disseisivit eum de uno mesuagio et dimidie virgatam terre. Et Michaelis venit et dicit quod assisa non debet iudiate.
# Prediction (word-level differences): primam etc. Et unde queritur quod disseisivit eum de uno mesuagio et dimidie virgatam terre. Et Michaelis venit et dicit quod assisa non debet iudiate.
# Image Path: work/processed_data/JUST1-734m6da_line_18.npy
# Ground Truth: tare potuit. Dicit enim quod idem Rogerus per longum tempus ante mortem suam feoffavit quendam Willelmum le Sermoner
# Prediction (char-level differences): tare potuit. Dicint ejum quod idem Rogerus per longum tempus ante mortem suam feoffavit quendam Willelmum le Sirmoner
# Prediction (word-level differences): tare potuit Dicint ejum quod idem Rogerus per logum tempus ante mortem suam feoffavit quendam Willelmum le Sirmoner
# Image Path: work/processed_data/JUST1-734m4_line_18.npy
# Ground Truth: ¶ Assisa venit recognitura si Willelmus de Kalverhale et Johannes filius ejus injuste etc. disseisiverunt Adam filium Petri de Kalverhall et Sibillam uxorem
# Prediction (char-level differences): ¶ Assisa venit recognitura si Willelmus de Baluerhale et Johannes filius ejus injuste etc. disseisivit Adam filium Petri de Kaluerhall et Sibillam uxorem
# Prediction (word-level differences): ¶ Assisa venit regnitura si Willelmus de Baluerhale et Johannes filius ejus injuste etc. disseisivit Adam filium Petri de Kaluerhall et Sibillam uxorem
# Image Path: work/processed_data/JUST1-734m5_line_16.npy
# Ground Truth: tulit assisam istam quia dicunt quod predictus Colemannus avunculus ipsius Colemanni non obit seisitus de predictis tenementis
# Prediction (char-level differences): tulit assisum istarm quia dicunt quod predictus Colemannus annusus ipsius Colemanni non obiit seisitus de predictis tenementis
# Prediction (word-level differences): tulit assisum istarm quia dicunt quod predictus Colemannus annusus ipsius Colemanni non obiit seisitus de predictis tenementis
# Image Path: work/processed_data/JUST1-734m4d_line_0.npy
# Ground Truth: ¶ assisa uenit recognitura si Iacobus de Audeleg Adam le Provost de Egemindon. Ricardus filius Willelmi. Willelmus le Blunt
# Prediction (char-level differences): ¶ Assisa venit recognitura si Jacobus de Auudeleg Adam le Pronost de Egemundon. Ricardus filius Willelmi. Willelmus le Blunt
# Prediction (word-level differences): ¶ Assisa venit recognitura si Jacobus de Auudelg Adam le Pronost de Egemundon Ricardus filius Willemi Willelmus le Blunt
# Image Path: work/processed_data/JUST1-734m14da_line_26.npy
# Ground Truth: similiter. Ideo fiat inde jurata.
# Prediction (char-level differences): similiter. Ideo fiat inde juratore.
# Prediction (word-level differences): similiter. Ideo fiat inde juratore.
# Image Path: work/processed_data/JUST1-734m11d_line_18.npy
# Ground Truth: nuit predictum tenementum. nisi ad terminum vite sue. Et de hoc ponit se super assisam.
# Prediction (char-level differences): nuit predictum tenementum. nisi ad terminum vite sue. Et de hoc ponit se super assisam.
# Prediction (word-level differences): nuit predictum tenementum nisi ad terminum vite sue. Et de hoc ponit se super assisam.
