# %%
from utils import highlight_differences
import os
import json
import matplotlib.pyplot as plt
import numpy as np

# %%
error_dir = "work/errors/train"
project_dir = "/home/efittsc1/projects/latin-transcription/"
error_dir = project_dir + error_dir

# %%
def visualise_result(data):
    image_path = data["filename"]
    image_name = os.path.basename(image_path)
    truth = data["truth"]
    pred = data["prediction"]

    image = np.load(os.path.join(project_dir, image_path))

    highlighted_pred_char = highlight_differences(pred, truth, level='char')
    highlighted_pred_word = highlight_differences(pred, truth, level='word')


    print(f"\nImage Path: {image_path}")
    print(f"Ground Truth: {truth}")
    print(f"Prediction (char-level differences): {highlighted_pred_char}")
    print(f"Prediction (word-level differences): {highlighted_pred_word}")


    plt.figure(figsize=(10, 4))
    plt.imshow(image, cmap='gray')
    plt.title(f"Line: {image_name}")
    plt.axis('off')
    plt.show()

# %%
for error_json in os.listdir(error_dir)[:10]:
    with open(os.path.join(error_dir, error_json), 'r') as f:
        data = json.load(f)
    visualise_result(error_json)
# Out:
# Image Path: work/processed_data/JUST1-734m15d_line_3.npy
# Ground Truth: Robertum de Wetemor filium suum de predicta terra. et ipsum inde in seisina posuit. Et postmodum penituit eum de facto suo. et ejecit
# Prediction (char-level differences): Robertus de Wetemor filium suum de predicta terra. et ipsum inde in seisina posuit. Et postinodum penituit eum de facto suo. et eiecit
# Prediction (word-level differences): Robertus de Wetemor filium suum de predicta terra. et ipsum inde in seisina posuit. Et postinodum penituit eum de facto suo et eiecit
# Image Path: work/processed_data/JUST1-820m18_line_10.npy
# Ground Truth: pertinentibus fuit in seisina de eadem libertate ita quod quendam Hugonem le Bret captum cum manuopere
# Prediction (char-level differences): pertinentibus fuit in seisina de eadem libertate. ita quod quodam Hugons le Bret captum cum manuoperx
# Prediction (word-level differences): pertinentibus fuit in seisina de eadem libertate. ita quod quodam Hugons le Bret captum cum manuoperx
# Image Path: work/processed_data/JUST1-277m15d_line_13.npy
# Ground Truth: tempore pacis tempore E. regis patris domini regis nunc capiendo inde expletia ad valenciam etc. Et de predicta Isabella
# Prediction (char-level differences): tempore pacis tempore Et. regis patris domini regis nunc capiendo inde expletu ad valenciam etc. Et de predicta Nsabella
# Prediction (word-level differences): tempore pacis tempore Et. regis patris domini regis nunc capiendo inde expletu ad valenciam etc. Et de predicta Nsabell
# Image Path: work/processed_data/JUST1-734m8_line_11.npy
# Ground Truth: tenementum est in Wrokewrthyn et quod idem Abbas ipsum inde disseisivit ponit se super assisam.
# Prediction (char-level differences): tenementum est in Wrokewrthyn. et quod idem Abbaas ipsum inde disseisivit ponit se super assisam.
# Prediction (word-level differences): tenementum est in Wrokewrthyn. et quod idem Abbaas ipsum inde dissesivit ponit se super assisam
# Image Path: work/processed_data/JUST1-734m18_line_15.npy
# Ground Truth: Et quia non habent terram in comitatu Buk set in comitatu Leycestr.
# Prediction (char-level differences): Et quia non habente qri. in coritatum Subb secs in comitatu Buk set in comitatu Leycestre
# Prediction (word-level differences): Et qua n habnte qri. in coritatum Subb secs in comitatum Leycestre
# Image Path: work/processed_data/JUST-633m12d_line_2.npy
# Ground Truth: communa pasture communicandi in sex acris prati cum omnimodis auseris --- quolibet anno a tempore falcacionis
# Prediction (char-level differences): communa pasture communicandi in sex acris prati cum omnnimodis auseriss --- quolibet anno a tempore falcacionis
# Prediction (word-level differences): comuna pasture communcandi in sex acris prati cum omnnimodis aueriss - quolibet anno atempore falcacionis
# Image Path: work/processed_data/JUST1-734m6d_line_13.npy
# Ground Truth: injuste etc. disseisiverunt Willelmum de Pynkelegh de libero tenemento suo in Pynkelegh post primam etc. Et unde queritur quod disseisiverunt eum de duabus
# Prediction (char-level differences): injuste etc. disseisiviunt Willelmum de Pynkelegh de libero tenemento suo in Pynkelegh post primam etc. Et unde queritur quod disseisivit eum de duabus
# Prediction (word-level differences): injuste etc. disseisiviut Willelum de Pynkelegh de libero tenemento suo in Pynkelegh post primam etc. Et unde queritur quod disseisivit eum deduabus
# Image Path: work/processed_data/JUST1-734m14_line_27.npy
# Ground Truth: Juliana non est propinquior heres ejus quia dicunt quod predicta Juliana nata fuit antequam mater sua fuisset desponsata. Et ideo consideratum
# Prediction (char-level differences): Juliana non est propinquior heres ejus. quia dicunt quod predicta Juliana nata fuit antequam murater sua fuisset desponsata. et ideo contratum
# Prediction (word-level differences): Julia non est propinquior heres ejus. quia dicunt quod predicta Julia nata fuit antequam murater sua fuisset desponsata. et ideo contr
# Image Path: work/processed_data/JUST1-633m120_line_26.npy
# Ground Truth: in Magna Brampton que sunt predicta tenementa petita per quem finem idem Philippus recognouit illam terram
# Prediction (char-level differences): in Magna Brampton que sunt predicta tenementa petita per quem finem idem Philippus recognosit illam terram
# Prediction (word-level differences): in Magna Brampton que sunt predicta tenementa petita per quem fnem idem Philipus recognosit illam terram
# Image Path: work/processed_data/JUST1-277m15d_line_31.npy
# Ground Truth: Nicholaus et Margeria dicunt quod cum in predicto scripto contineatur quod ipsa Margeria terram predictam dedisse debuit
# Prediction (char-level differences): Nsicholaus et Margeria dicunt quod cum in predicto scripto contineatur quod ipsa Margeria terram predictam dedisse debuit
# Prediction (word-level differences): Nsicholaus et Margeria dicunt quod cum in predicto scripto contineatur quod ipsa Margeria terram predictam dedisse debuit
