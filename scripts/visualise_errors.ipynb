# %%
from utils import highlight_differences
import os
import json
import matplotlib.pyplot as plt
import numpy as np

# %%
#error_dir = "work/errors/val"
error_dir = "work/max_data_-1/errors/train"
project_dir = "/home/efittsc1/projects/latin-transcription/"
error_dir = project_dir + error_dir
show_n_errors = 10

# %%
def visualise_result(data):
    image_path = data["filename"]
    image_name = os.path.basename(image_path)
    truth = data["truth"]
    pred = data["prediction"]

    image = np.load(os.path.join(project_dir, image_path))

    highlighted_pred_char = highlight_differences(pred, truth, level='char')
    highlighted_pred_word = highlight_differences(pred, truth, level='word')


    print(f"\nImage Path: {image_path}")
    print(f"Ground Truth:\t\t{truth}")
    print(f"Prediction (char_diff): {highlighted_pred_char}")
    print(f"Prediction (char_diff): {highlighted_pred_word}")


    plt.figure(figsize=(10, 4))
    plt.imshow(image, cmap='gray')
    plt.title(f"Line: {image_name}")
    plt.axis('off')
    plt.show()

# %%
for error_json in os.listdir(error_dir)[:min(show_n_errors, len(os.listdir(error_dir)))]:
    with open(os.path.join(error_dir, error_json), 'r') as f:
        data = json.load(f)
    visualise_result(data)
# Out:
# Image Path: work/processed_data/memb1_line_3.npy
# Ground Truth:		valenciam octo librarum ibidem inventa ceperunt et asportaverunt et herbam suam ibidem nuper crescentem ad valenciam quadraginta
# Prediction (char_diff): valenciam octo librarum ibidem inventa ceperunt et asportaverunt et herbam suam ibidem nuper crescentem ad valenciam quad araginca
# Prediction (char_diff): valenciam octo libraum ibidem invent ceperunt etasotavernt et hebam suam ibidem nuper crescentem ad valenciam quad arinca
# Image Path: work/processed_data/JUST1-734m14d_line_10.npy
# Ground Truth:		Et de predicta dimidia quam warantizant dicunt quod assisa non debet inde fieri quia dicunt quod idem Willelmus post mortem predicti
# Prediction (char_diff): Et de predicta dimidia qud verantiet dicunt quod assisa non debet inde fieri quia dicunt quod idem Willelmus eost matem predicti
# Prediction (char_diff): Et de predicta dimidia qud veratiet dicunt quod assia non debet inde fieri quia dicunt quod idem Willelmus eost matem predicti
# Image Path: work/processed_data/JUST1-633m48d_line_23.npy
# Ground Truth:		non venit. Et fuit petens. Ideo predictus Thomas inde sine die et predictus Willelmus abbas et plegii sui de prosequendo in
# Prediction (char_diff): non venit. Et fuit petens. Ideo predictus Thomas inde sine die et predictus Willelmus abbas et plegii sui de prosequendo in
# Prediction (char_diff): on venit. Et fuit petens. Ideo predictus Thomas inde sine die et predictus Willelmus abbas et plegii sui de prosequendo in
# Image Path: work/processed_data/JUST1-633m3d_line_15.npy
# Ground Truth:		predicti Willelmus et alii ipsos inde iniuste disseisiuerunt etc. Et hoc petunt quod inquiratur per assisam etc. Et predicti
# Prediction (char_diff): predicti Willelmus et alii ipsos inde iniuste disseisiuerunt etc. Et hoc petunt quod inquiratur per assisam etc. Et predicti
# Prediction (char_diff): predicti Willelmus et alii ipsos inde iniuste disseisiuerunt etc. Et hoc petunt quod inquirat per assisam etc. Et predicti
# Image Path: work/processed_data/JUST1-734m17da_line_10.npy
# Ground Truth:		valenciam xl librarum.
# Prediction (char_diff): valencit n libradum.
# Prediction (char_diff): valenit n libradum
# Image Path: work/processed_data/JUST1-734m7_line_10.npy
# Ground Truth:		sue ita quod eam tenuit fere per annum pacifice quousque predictus Ricardus ipsum inde disseisivit et de hoc ponit se super assisam.
# Prediction (char_diff): sue ita quod eam tenuit fere per annum pacifice quousque predictus Ricardus ipsum inde disseisivit et de hoc ponit se super assisam.
# Prediction (char_diff): sue ita quod eam tenuit fere per annum pacifice quousque predictus Ricardus ipsum inde disseisivit et de hoc ponit se super assisam
# Image Path: work/processed_data/JUST1-633m48d_line_13.npy
# Ground Truth:		redditum in dotem ex dotacione predicti Iohannis de Boketon quondam viri etc. de hereditate predicti Thome
# Prediction (char_diff): redditum in dotem ex dotacione predicti Iohannis de Boketon quondam viri etc. de hereditate predicti Thome
# Prediction (char_diff): redditum in dotem e dotacione predicti Iohannis de Boketon quondam viri etc. de hereditate predicti Thome
# Image Path: work/processed_data/JUST1-633m48d_line_9.npy
# Ground Truth:		Willelmus de Nutriuilla quondam Abbas etc. predecessor. predicti prebendarii etc. fuit seisitus de predictis redditubus
# Prediction (char_diff): Willelmus de Nutriuilla quondam Abbas etc. predecessor. predicti prebendarii etc. fuit seisitus de predictis redditubuis
# Prediction (char_diff): Willelmus de Nutriuilla quondam Abbas etc. predecessor. predicti prebendarii etc. fuit seisitus de predictis redditubuis
# Image Path: work/processed_data/JUST1-734m13d_line_22.npy
# Ground Truth:		eadem villa Et de hoc ponit se super patriam
# Prediction (char_diff): endem villa et de nt ponit se su foioner patriam
# Prediction (char_diff): endem villa et de nt ponit se su foionem
# Image Path: work/processed_data/JUST1-632m3d_line_10.npy
# Ground Truth:		fugit et reddidit se suspectum de morte predicta. Ideo idem Thomas allocutus qualiter se velit de
# Prediction (char_diff): fustet reduidit et reddidit se suspectum - morte pre de. Ideo i--omas allocntus nt voliter se velit de
# Prediction (char_diff): fustet reduidit et suspet - mort pre de. Ideo i--omas allocntus nt volit
